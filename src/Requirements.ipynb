# %% [markdown]
# ### Dependencies
# Watermark used to capture dependencies

# %%
! pip install geopandas
import pandas as pd
import numpy as np
import warnings
import zipfile
from bs4 import BeautifulSoup
import requests
import geopandas as gpd
import fiona
import matplotlib.pyplot as plt
import seaborn as sns

# %%
! pip install watermark

# %%
# %load_ext watermark
# %watermark -v -m -p pandas,numpy,warnings,zipfile,bs4,requests,geopandas,fiona,matplotlib,seaborn
# Out:
# The watermark extension is already loaded. To reload it, use:
#   %reload_ext watermark
# Python implementation: CPython
# Python version       : 3.10.11
# IPython version      : 8.13.2
#
# pandas    : 2.0.1
# numpy     : 1.23.5
# warnings  : unknown
# zipfile   : unknown
# bs4       : 4.12.2
# requests  : 2.29.0
# geopandas : 0.14.0
# fiona     : 1.9.4.post1
# matplotlib: 3.7.1
# seaborn   : 0.12.2
#
# Compiler    : GCC 11.3.0
# OS          : Linux
# Release     : 5.15.0-1017-aws
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 32
# Architecture: 64bit

# %% [markdown]
# Watermark:</br>
# The watermark extension is already loaded. To reload it, use:</br>
#   %reload_ext watermark</br>
# Python implementation: CPython</br>
# Python version       : 3.10.11</br>
# IPython version      : 8.13.2</br>
# </br>
# pandas    : 2.0.1</br>
# numpy     : 1.23.5</br>
# warnings  : unknown</br>
# zipfile   : unknown</br>
# bs4       : 4.12.2</br>
# requests  : 2.29.0</br>
# geopandas : 0.14.0</br>
# fiona     : 1.9.4.post1</br>
# matplotlib: 3.7.1</br>
# seaborn   : 0.12.2</br>
# </br>
